# %% [markdown]
# Read the data and collect all the necessary information

# %%
import pandas as pd  
import re

# %%
def analyze_columns(file_path):  
    try:  
        df = pd.read_csv(file_path, nrows=0)  
        columns = df.columns.tolist()  
        
        # Initialize dictionaries to count occurrences  
        metric_counts = {}  
        industry_counts = {}  
        metric_pattern = r'\((.*?)\)'  
        
        for col in columns:   
            if col == 'Title':  
                continue  
                
            metric_match = re.search(metric_pattern, col)  
            if metric_match:  
                metric_raw = metric_match.group(1)  
                metric = ' '.join(metric_raw.strip().split()).lower()  
                metric_counts[metric] = metric_counts.get(metric, 0) + 1  
                
                industry_match = re.search(r'^(.*?)\s*\(', col)  
                if industry_match:  
                    industry = industry_match.group(1).strip()  
                    # Add to industry counts if not already counted  
                    if industry not in industry_counts:  
                        industry_counts[industry] = 1  

        total_metrics = sum(metric_counts.values())  
        sorted_metrics = sorted(  
            metric_counts.items(), key=lambda item: item[1], reverse=True  
        )  
        
        sorted_industries = sorted(industry_counts.keys())  

        print("\nMetrics Analysis:")  
        print(f"There are {len(sorted_metrics)} different types of metrics:")  
        for i, (metric, count) in enumerate(sorted_metrics, 1):  
            percentage = (count / total_metrics) * 100  
            display_metric = ' '.join(word.capitalize() for word in metric.split())  
            print(f"{i}. {display_metric}")  
            print(f"   Occurrence count: {count} ({percentage:.1f}%)")  

        print("\nIndustry sector analysis:")  
        print(f"There are {len(sorted_industries)} different industry sectors:")  
        for i, industry in enumerate(sorted_industries, 1):  
            print(f"{i}. {industry}")  

    except Exception as e:  
        print(f"An error occurred: {e}")  
        import traceback  
        traceback.print_exc()  

# File path  
file_path = 'mgdp.csv'  
analyze_columns(file_path)
# Out:
# Metrics Analysis:
# There are 9 different types of metrics:
# 1. Index 1dp
#    Occurrence count: 23 (11.1%)
# 2. Period On Period Growth
#    Occurrence count: 23 (11.1%)
# 3. Period On Period 1 Year Ago Growth
#    Occurrence count: 23 (11.1%)
# 4. 3 Month On 3 Month Growth
#    Occurrence count: 23 (11.1%)
# 5. 3m On 3m 1 Year Ago Growth
#    Occurrence count: 23 (11.1%)
# 6. Period On Period Contribution
#    Occurrence count: 23 (11.1%)
# 7. Period On Period 1 Year Ago Contribution
#    Occurrence count: 23 (11.1%)
# 8. 3 Month On 3 Month Contribution
#    Occurrence count: 23 (11.1%)
# 9. 3m On 3m 1 Year Ago Contribution
#    Occurrence count: 23 (11.1%)
#
# Industry sector analysis:
# There are 23 different industry sectors:
# 1. Accommodation and food service activities
# 2. Activities of housholds as employers;Undiff goods & services
# 3. Administrative and Support Service Activities
# 4. Agriculture, Forestry and Fishing
# 5. Arts, Entertainment and Recreation
# 6. Construction
# 7. Education
# 8. Electricity, gas, steam and air conditioning supply
# 9. Financial and insurance activities
# 10. Gross Value Added - Monthly
# 11. Human health and social work activities
# 12. Information and communication
# 13. Manufacturing
# 14. Mining and Quarrying
# 15. Other service activities
# 16. Production Industries - Total
# 17. Professional, scientific and technical activities
# 18. Public admin and defence; Compulsory social security
# 19. Real estate activities
# 20. Service Industries - Total
# 21. Transportation and Storage
# 22. Water supply; Sewerage,waste management & remediation activities
# 23. Wholesale & retail trade; Repair of motor vehicles/cycles

# %% [markdown]
# Data clean (delete all ':CVM SA')

# %%
def clean_column_names(input_file, output_file='mgdp1.csv'):  
    """  
    Clean column names by removing ':CVM SA' and other unnecessary parts  
    while maintaining the "Industry (Metric)" format.  
    """  
    try:  
        # Read the CSV file  
        df = pd.read_csv(input_file)  
        
        # Get current column names  
        old_columns = df.columns.tolist()  
        
        # Clean column names by removing unnecessary parts  
        new_columns = []  
        
        for col in old_columns:  
            # Remove the ':CVM SA' suffix from column names  
            cleaned_col = re.sub(r'\s*:CVM SA\s*$', '', col)  
            
            # Add the cleaned column name to our list  
            new_columns.append(cleaned_col)  
        
        # Rename the dataframe columns  
        df.columns = new_columns  
        
        # Save the cleaned dataframe to a new CSV file  
        df.to_csv(output_file, index=False)  
        
        print(f"Successfully cleaned column names and saved to {output_file}")  
        print("\nOriginal vs. Cleaned Column Names (first 5):")  
        for i in range(min(5, len(old_columns))):  
            print(f"Original: {old_columns[i]}")  
            print(f"Cleaned:  {new_columns[i]}")  
            print("")  
        
        return df  
    
    except Exception as e:  
        print(f"Error cleaning column names: {e}")  
        import traceback  
        traceback.print_exc()  
        return None  

# Usage  
input_file = "mgdp.csv"  # Replace with your actual input file path  
output_file = "mgdp1.csv"  
cleaned_df = clean_column_names(input_file, output_file)
# Out:
# Successfully cleaned column names and saved to mgdp1.csv
#
# Original vs. Cleaned Column Names (first 5):
# Original: Title
# Cleaned:  Title
#
# Original: Gross Value Added - Monthly (Index 1dp) :CVM SA
# Cleaned:  Gross Value Added - Monthly (Index 1dp)
#
# Original: Agriculture, Forestry and Fishing (Index 1dp) :CVM SA
# Cleaned:  Agriculture, Forestry and Fishing (Index 1dp)
#
# Original: Production Industries - Total (Index 1dp) :CVM SA
# Cleaned:  Production Industries - Total (Index 1dp)
#
# Original: Mining and Quarrying (Index 1dp) :CVM SA
# Cleaned:  Mining and Quarrying (Index 1dp)

# %% [markdown]
# Data reclass
# Date, Industry1 (metric 1), Industry1 (metric2), Industry2 (Metric1) ,...,

# %%
def process_wide_format(input_file, output_file='mgdp1.csv'):  
    """  
    Process a CSV file to ensure it has proper "Industry (Metric)" column headers  
    and save it as a new CSV file for web interaction.  
    
    Parameters:  
    - input_file: Path to the input CSV file  
    - output_file: Path to save the processed CSV (default: 'mgdp1.csv')  
    """  
    try:  
        # Read the CSV file  
        df = pd.read_csv(input_file)  
        
        # Identify column names  
        columns = df.columns.tolist()  
        
        # Assuming first column is Date/Title  
        date_col = columns[0]  
        data_cols = columns[1:]  
        
        # Ensure proper column naming  
        new_columns = [date_col]  # Keep date/time column as is  
        
        for col in data_cols:  
            # Check if column already follows "Industry (Metric)" format  
            if re.match(r'^.*\(.*\).*$', col):  
                new_columns.append(col)  
            else:  
                # This handles columns that don't follow the format  
                # You may need to adjust this logic based on your actual data  
                new_columns.append(f"Unknown ({col})")  
        
        # Rename columns in the dataframe  
        df.columns = new_columns  
        
        # Convert date column to datetime if it contains dates  
        if df[date_col].dtype == 'object':  
            try:  
                df[date_col] = pd.to_datetime(df[date_col])  
                # Format date as YYYY-MM-DD  
                df[date_col] = df[date_col].dt.strftime('%Y-%m-%d')  
            except:  
                # If conversion fails, keep as is (might be a different type of identifier)  
                pass  
        
        # Save the processed dataframe  
        df.to_csv(output_file, index=False)  
        print(f"Successfully processed and saved to {output_file}")  
        
        # Display sample of the processed dataframe  
        print("\nSample of processed data:")  
        print(df.head())  
        
        # Display column information  
        print("\nColumn names in the processed file:")  
        for i, col in enumerate(df.columns):  
            print(f"{i}: {col}")  
            
        return df  
        
    except Exception as e:  
        print(f"Error processing file: {e}")  
        import traceback  
        traceback.print_exc()  
        return None  

# Usage  
input_file = "mgdp1.csv"  # Replace with your actual input file  
output_file = "mgdp2.csv"  
processed_df = process_wide_format(input_file, output_file)
# Out:
# Successfully processed and saved to mgdp2.csv
#
# Sample of processed data:
#       Title Gross Value Added - Monthly (Index 1dp)  \
# 0      CDID                                    ECY2
# 1  2016 JAN                                    91.2
# 2  2016 FEB                                    91.4
# 3  2016 MAR                                    91.6
# 4  2016 APR                                    92.1
#
#   Agriculture, Forestry and Fishing (Index 1dp)  \
# 0                                          ECY3
# 1                                          90.6
# 2                                            88
# 3                                          87.3
# 4                                          87.5
#
#   Production Industries - Total (Index 1dp) Mining and Quarrying (Index 1dp)  \
# 0                                      ECY4                             ECY5
# 1                                      99.3                            116.6
# 2                                      99.1                            119.6
# 3                                      99.1                            119.5
# 4                                     101.5                            121.2
#
#   Manufacturing (Index 1dp)  \
# 0                      ECY6
# 1                      96.1
# 2                      95.9
# 3                      95.2
# 4                      97.5
#
#   Electricity, gas, steam and air conditioning supply(Index 1dp)  \
# 0                                               ECY7
# 1                                                130
# 2                                              128.7
# 3                                              134.4
# 4                                              140.7
#
#   Water supply; Sewerage,waste management & remediation activities (Index 1dp)  \
# 0                                               ECY8
# 1                                               91.7
# 2                                               90.8
# 3                                               90.9
# 4                                               91.5
#
#   Construction (Index 1dp) Service Industries - Total (Index 1dp)  ...  \
# 0                     ECY9                                   ECYC  ...
# 1                     94.6                                   90.1  ...
# 2                       94                                   90.5  ...
# 3                     93.4                                   90.7  ...
# 4                     93.3                                     91  ...
#
#   Financial and insurance activities (3m on 3m 1 year ago contribution)  \
# 0                                               EDNL
# 1                                              -0.41
# 2                                              -0.21
# 3                                              -0.01
# 4                                               0.13
#
#   Real estate activities (3m on 3m 1 year ago contribution)  \
# 0                                               EDNM
# 1                                               0.57
# 2                                               0.58
# 3                                               0.58
# 4                                                0.5
#
#   Professional, scientific and technical activities (3m on 3m 1 year ago contribution)  \
# 0                                               EDNN
# 1                                               0.06
# 2                                               0.02
# 3                                              -0.01
# 4                                               0.03
#
#   Administrative and Support Service Activities (3m on 3m 1 year ago contribution)  \
# 0                                               EDNO
# 1                                               0.14
# 2                                               0.13
# 3                                               0.12
# 4                                               0.07
#
#   Public admin and defence; Compulsory social security (3m on 3m 1 year ago contribution)  \
# 0                                               EDNP
# 1                                               0.09
# 2                                               0.12
# 3                                               0.16
# 4                                               0.17
#
#   Education (3m on 3m 1 year ago contribution)  \
# 0                                         EDNQ
# 1                                          0.1
# 2                                         0.08
# 3                                         0.05
# 4                                         0.04
#
#   Human health and social work activities (3m on 3m 1 year ago contribution)  \
# 0                                               EDNR
# 1                                               0.32
# 2                                               0.34
# 3                                               0.33
# 4                                                0.3
#
#   Arts, Entertainment and Recreation (3m on 3m 1 year ago contribution)  \
# 0                                               EDNS
# 1                                              -0.04
# 2                                              -0.06
# 3                                              -0.07
# 4                                              -0.08
#
#   Other service activities (3m on 3m 1 year ago contribution)  \
# 0                                               EDNT
# 1                                               0.04
# 2                                               0.02
# 3                                               0.03
# 4                                               0.03
#
#   Activities of housholds as employers;Undiff goods & services (3m on 3m 1 year ago contribution)
# 0                                               EDNU
# 1                                               0.02
# 2                                               0.02
# 3                                               0.01
# 4                                               0.02
#
# [5 rows x 208 columns]
#
# Column names in the processed file:
# 0: Title
# 1: Gross Value Added - Monthly (Index 1dp)
# 2: Agriculture, Forestry and Fishing (Index 1dp)
# 3: Production Industries - Total (Index 1dp)
# 4: Mining and Quarrying (Index 1dp)
# 5: Manufacturing (Index 1dp)
# 6: Electricity, gas, steam and air conditioning supply(Index 1dp)
# 7: Water supply; Sewerage,waste management & remediation activities (Index 1dp)
# 8: Construction (Index 1dp)
# 9: Service Industries - Total (Index 1dp)
# 10: Wholesale & retail trade; Repair of motor vehicles/cycles (Index 1dp)
# 11: Transportation and Storage (Index 1dp)
# 12: Accommodation and food service activities (Index 1dp)
# 13: Information and communication (Index 1dp)
# 14: Financial and insurance activities (Index 1dp)
# 15: Real estate activities (Index 1dp)
# 16: Professional, scientific and technical activities (Index 1dp)
# 17: Administrative and Support Service Activities (Index 1dp)
# 18: Public admin and defence; Compulsory social security (Index 1dp)
# 19: Education (Index 1dp)
# 20: Human health and social work activities (Index 1dp)
# 21: Arts, Entertainment and Recreation (Index 1dp)
# 22: Other service activities (Index 1dp)
# 23: Activities of housholds as employers;Undiff goods & services (Index 1dp)
# 24: Gross Value Added - Monthly (period on period growth)
# 25: Agriculture, Forestry and Fishing (period on period growth)
# 26: Production Industries - Total (period on period growth)
# 27: Mining and Quarrying (period on period growth)
# 28: Manufacturing (period on period growth)
# 29: Electricity, gas, steam and air conditioning supply(period on period growth)
# 30: Water supply; Sewerage,waste management & remediation activities (period on period growth)
# 31: Construction (period on period growth)
# 32: Service Industries - Total (period on period growth)
# 33: Wholesale & retail trade; Repair of motor vehicles/cycles (period on period growth)
# 34: Transportation and Storage (period on period growth)
# 35: Accommodation and food service activities (period on period growth)
# 36: Information and communication (period on period growth)
# 37: Financial and insurance activities (period on period growth)
# 38: Real estate activities (period on period growth)
# 39: Professional, scientific and technical activities (period on period growth)
# 40: Administrative and Support Service Activities (period on period growth)
# 41: Public admin and defence; Compulsory social security (period on period growth)
# 42: Education (period on period growth)
# 43: Human health and social work activities (period on period growth)
# 44: Arts, Entertainment and Recreation (period on period growth)
# 45: Other service activities (period on period growth)
# 46: Activities of housholds as employers;Undiff goods & services (period on period growth)
# 47: Gross Value Added - Monthly (period on period 1 year ago growth )
# 48: Agriculture, Forestry and Fishing (period on period 1 year ago growth)
# 49: Production Industries - Total (period on period 1 year ago growth)
# 50: Mining and Quarrying (period on period 1 year ago growth)
# 51: Manufacturing (period on period 1 year ago growth)
# 52: Electricity, gas, steam and air conditioning supply(period on period 1 year ago growth)
# 53: Water supply; Sewerage,waste management & remediation activities (period on period 1 year ago growth)
# 54: Construction (period on period 1 year ago growth)
# 55: Service Industries - Total (period on period 1 year ago growth)
# 56: Wholesale & retail trade; Repair of motor vehicles/cycles (period on period 1 year ago growth)
# 57: Transportation and Storage (period on period 1 year ago growth)
# 58: Accommodation and food service activities (period on period 1 year ago growth)
# 59: Information and communication (period on period 1 year ago growth)
# 60: Financial and insurance activities (period on period 1 year ago growth)
# 61: Real estate activities (period on period 1 year ago growth)
# 62: Professional, scientific and technical activities (period on period 1 year ago growth)
# 63: Administrative and Support Service Activities (period on period 1 year ago growth)
# 64: Public admin and defence; Compulsory social security (period on period 1 year ago growth)
# 65: Education (period on period 1 year ago growth)
# 66: Human health and social work activities (period on period 1 year ago growth)
# 67: Arts, Entertainment and Recreation (period on period 1 year ago growth)
# 68: Other service activities (period on period 1 year ago growth)
# 69: Activities of housholds as employers;Undiff goods & services (period on period 1 year ago growth)
# 70: Gross Value Added - Monthly (3 month on 3 month growth)
# 71: Agriculture, Forestry and Fishing (3 month on 3 month growth)
# 72: Production Industries - Total (3 month on 3 month growth)
# 73: Mining and Quarrying (3 month on 3 month growth)
# 74: Manufacturing (3 month on 3 month growth)
# 75: Electricity, gas, steam and air conditioning supply(3 month on 3 month growth)
# 76: Water supply; Sewerage,waste management & remediation activities (3 month on 3 month growth)
# 77: Construction (3 month on 3 month growth)
# 78: Service Industries - Total (3 month on 3 month growth)
# 79: Wholesale & retail trade; Repair of motor vehicles/cycles (3 month on 3 month growth)
# 80: Transportation and Storage (3 month on 3 month growth)
# 81: Accommodation and food service activities (3 month on 3 month growth)
# 82: Information and communication (3 month on 3 month growth)
# 83: Financial and insurance activities (3 month on 3 month growth)
# 84: Real estate activities (3 month on 3 month growth)
# 85: Professional, scientific and technical activities (3 month on 3 month growth)
# 86: Administrative and Support Service Activities (3 month on 3 month growth)
# 87: Public admin and defence; Compulsory social security (3 month on 3 month growth)
# 88: Education (3 month on 3 month growth)
# 89: Human health and social work activities (3 month on 3 month growth)
# 90: Arts, Entertainment and Recreation (3 month on 3 month growth)
# 91: Other service activities (3 month on 3 month growth)
# 92: Activities of housholds as employers;Undiff goods & services (3 month on 3 month growth)
# 93: Gross Value Added - Monthly (3m on 3m 1 year ago growth)
# 94: Agriculture, Forestry and Fishing (3m on 3m 1 year ago growth)
# 95: Production Industries - Total (3m on 3m 1 year ago growth)
# 96: Mining and Quarrying (3m on 3m 1 year ago growth)
# 97: Manufacturing (3m on 3m 1 year ago growth)
# 98: Electricity, gas, steam and air conditioning supply(3m on 3m 1 year ago growth)
# 99: Water supply; Sewerage,waste management & remediation activities (3m on 3m 1 year ago growth)
# 100: Construction (3m on 3m 1 year ago growth)
# 101: Service Industries - Total (3m on 3m 1 year ago growth)
# 102: Wholesale & retail trade; Repair of motor vehicles/cycles (3m on 3m 1 year ago growth)
# 103: Transportation and Storage (3m on 3m 1 year ago growth)
# 104: Accommodation and food service activities (3m on 3m 1 year ago growth)
# 105: Information and communication (3m on 3m 1 year ago growth)
# 106: Financial and insurance activities (3m on 3m 1 year ago growth)
# 107: Real estate activities (3m on 3m 1 year ago growth)
# 108: Professional, scientific and technical activities (3m on 3m 1 year ago growth)
# 109: Administrative and Support Service Activities (3m on 3m 1 year ago growth)
# 110: Public admin and defence; Compulsory social security (3m on 3m 1 year ago growth)
# 111: Education (3m on 3m 1 year ago growth)
# 112: Human health and social work activities (3m on 3m 1 year ago growth)
# 113: Arts, Entertainment and Recreation (3m on 3m 1 year ago growth)
# 114: Other service activities (3m on 3m 1 year ago growth)
# 115: Activities of housholds as employers;Undiff goods & services (3m on 3m 1 year ago growth)
# 116: Gross Value Added - Monthly (period on period contribution)
# 117: Agriculture, Forestry and Fishing (period on period contribution)
# 118: Production Industries - Total (period on period contribution)
# 119: Mining and Quarrying (period on period contribution)
# 120: Manufacturing (period on period contribution)
# 121: Electricity, gas, steam and air conditioning supply(period on period contribution)
# 122: Water supply; Sewerage,waste management & remediation activities (period on period contribution)
# 123: Construction (period on period contribution)
# 124: Service Industries - Total (period on period contribution)
# 125: Wholesale & retail trade; Repair of motor vehicles/cycles (period on period contribution)
# 126: Transportation and Storage (period on period contribution)
# 127: Accommodation and food service activities (period on period contribution)
# 128: Information and communication (period on period contribution)
# 129: Financial and insurance activities (period on period contribution)
# 130: Real estate activities (period on period contribution)
# 131: Professional, scientific and technical activities (period on period contribution)
# 132: Administrative and Support Service Activities (period on period contribution)
# 133: Public admin and defence; Compulsory social security (period on period contribution)
# 134: Education (period on period contribution)
# 135: Human health and social work activities (period on period contribution)
# 136: Arts, Entertainment and Recreation (period on period contribution)
# 137: Other service activities (period on period contribution)
# 138: Activities of housholds as employers;Undiff goods & services (period on period contribution)
# 139: Gross Value Added - Monthly (period on period 1 year ago contribution )
# 140: Agriculture, Forestry and Fishing (period on period 1 year ago contribution )
# 141: Production Industries - Total (period on period 1 year ago contribution )
# 142: Mining and Quarrying (period on period 1 year ago contribution )
# 143: Manufacturing (period on period 1 year ago contribution )
# 144: Electricity, gas, steam and air conditioning supply(period on period 1 year ago contribution )
# 145: Water supply; Sewerage,waste management & remediation activities (period on period 1 year ago contribution )
# 146: Construction (period on period 1 year ago contribution )
# 147: Service Industries - Total (period on period 1 year ago contribution )
# 148: Wholesale & retail trade; Repair of motor vehicles/cycles (period on period 1 year ago contribution )
# 149: Transportation and Storage (period on period 1 year ago contribution )
# 150: Accommodation and food service activities (period on period 1 year ago contribution )
# 151: Information and communication (period on period 1 year ago contribution )
# 152: Financial and insurance activities (period on period 1 year ago contribution )
# 153: Real estate activities (period on period 1 year ago contribution )
# 154: Professional, scientific and technical activities (period on period 1 year ago contribution )
# 155: Administrative and Support Service Activities (period on period 1 year ago contribution )
# 156: Public admin and defence; Compulsory social security (period on period 1 year ago contribution )
# 157: Education (period on period 1 year ago contribution )
# 158: Human health and social work activities (period on period 1 year ago contribution )
# 159: Arts, Entertainment and Recreation (period on period 1 year ago contribution )
# 160: Other service activities (period on period 1 year ago contribution )
# 161: Activities of housholds as employers;Undiff goods & services (period on period 1 year ago contribution )
# 162: Gross Value Added - Monthly (3 month on 3 month contribution)
# 163: Agriculture, Forestry and Fishing (3 month on 3 month contribution)
# 164: Production Industries - Total (3 month on 3 month contribution)
# 165: Mining and Quarrying (3 month on 3 month contribution)
# 166: Manufacturing (3 month on 3 month contribution)
# 167: Electricity, gas, steam and air conditioning supply(3 month on 3 month contribution)
# 168: Water supply; Sewerage,waste management & remediation activities (3 month on 3 month contribution)
# 169: Construction (3 month on 3 month contribution)
# 170: Service Industries - Total (3 month on 3 month contribution)
# 171: Wholesale & retail trade; Repair of motor vehicles/cycles (3 month on 3 month contribution)
# 172: Transportation and Storage (3 month on 3 month contribution)
# 173: Accommodation and food service activities (3 month on 3 month contribution)
# 174: Information and communication (3 month on 3 month contribution)
# 175: Financial and insurance activities (3 month on 3 month contribution)
# 176: Real estate activities (3 month on 3 month contribution)
# 177: Professional, scientific and technical activities (3 month on 3 month contribution)
# 178: Administrative and Support Service Activities (3 month on 3 month contribution)
# 179: Public admin and defence; Compulsory social security (3 month on 3 month contribution)
# 180: Education (3 month on 3 month contribution)
# 181: Human health and social work activities (3 month on 3 month contribution)
# 182: Arts, Entertainment and Recreation (3 month on 3 month contribution)
# 183: Other service activities (3 month on 3 month contribution)
# 184: Activities of housholds as employers;Undiff goods & services (3 month on 3 month contribution)
# 185: Gross Value Added - Monthly (3m on 3m 1 year ago contribution)
# 186: Agriculture, Forestry and Fishing (3m on 3m 1 year ago contribution)
# 187: Production Industries - Total (3m on 3m 1 year ago contribution)
# 188: Mining and Quarrying (3m on 3m 1 year ago contribution)
# 189: Manufacturing (3m on 3m 1 year ago contribution)
# 190: Electricity, gas, steam and air conditioning supply(3m on 3m 1 year ago contribution)
# 191: Water supply; Sewerage,waste management & remediation activities (3m on 3m 1 year ago contribution)
# 192: Construction (3m on 3m 1 year ago contribution)
# 193: Service Industries - Total (3m on 3m 1 year ago contribution)
# 194: Wholesale & retail trade; Repair of motor vehicles/cycles (3m on 3m 1 year ago contribution)
# 195: Transportation and Storage (3m on 3m 1 year ago contribution)
# 196: Accommodation and food service activities (3m on 3m 1 year ago contribution)
# 197: Information and communication (3m on 3m 1 year ago contribution)
# 198: Financial and insurance activities (3m on 3m 1 year ago contribution)
# 199: Real estate activities (3m on 3m 1 year ago contribution)
# 200: Professional, scientific and technical activities (3m on 3m 1 year ago contribution)
# 201: Administrative and Support Service Activities (3m on 3m 1 year ago contribution)
# 202: Public admin and defence; Compulsory social security (3m on 3m 1 year ago contribution)
# 203: Education (3m on 3m 1 year ago contribution)
# 204: Human health and social work activities (3m on 3m 1 year ago contribution)
# 205: Arts, Entertainment and Recreation (3m on 3m 1 year ago contribution)
# 206: Other service activities (3m on 3m 1 year ago contribution)
# 207: Activities of housholds as employers;Undiff goods & services (3m on 3m 1 year ago contribution)
# /tmp/ipykernel_5948/1614449950.py:39: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[date_col] = pd.to_datetime(df[date_col])
